# %% [markdown]
# ## Building and Training the Model

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
print("Num GPUs Available: ", tf.config.list_physical_devices('GPU'))
# Out:
# Num GPUs Available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load and preprocess dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255, test_images / 255

# %%
print("Training:",train_images.shape)
print("Testing:",test_images.shape)
# Out:
# Training: (50000, 32, 32, 3)
# Testing: (10000, 32, 32, 3)

# %%
for i in range(0,9):
    plt.subplot(330+1+i)
    plt.imshow(train_images[i])
plt.show()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
#Setup data augmentation
traingen = ImageDataGenerator(
    rotation_range=0,
    horizontal_flip=True,
    vertical_flip=False,
    width_shift_range=0.1,
    height_shift_range=0.1
    )
traingen.fit(train_images)

# %%
#Show example augmented images
for X_batch, y_batch in traingen.flow(train_images, train_labels, batch_size=9):
    for i in range(0,9):
        plt.subplot(330+1+i)
        plt.imshow(X_batch[i])
    plt.show()
    break

# %%
#make images
train_images = train_images.reshape(train_images.shape[0], 32, 32, 3)
test_images = test_images.reshape(test_images.shape[0], 32, 32, 3)
input_shape = (32, 32, 1)
print('train_images shape:', train_images.shape)
print('test_images shape:', test_images.shape)
print(train_images.shape[0], 'train samples')
print(test_images.shape[0], 'test samples')
# Out:
# train_images shape: (50000, 32, 32, 3)
# test_images shape: (10000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
convModel = models.Sequential([
    #3x3_96    
    layers.Conv2D(96, (3,3), activation='relu', input_shape=(32,32,3),
                  padding='same', name='3x3_1'),
    layers.Conv2D(96, (3,3), activation='relu', 
                  padding='same', name='3x3_2'),
    layers.Conv2D(96, (3,3), activation='relu', 
                  padding='valid', strides=[2,2], name='poolconv_1'),
    layers.Dropout(0.5),
    
    #3x3_192
    layers.Conv2D(192, (3,3), activation='relu', input_shape=(32, 32, 3),
                  padding='same', name='3x3_3'),
    layers.Conv2D(192, (3,3), activation='relu', 
                  padding='same', name='3x3_4'),
    layers.Conv2D(192, (3,3), activation='relu', 
                  padding='valid', strides=[2,2], name='poolconv_2'),
    layers.Dropout(0.5),
    
    #3x3&1x1
    layers.Conv2D(192, (3,3), activation='relu', 
                  padding='same', name='3x3_6'),
    layers.Conv2D(192, (1,1), activation='relu', 
                  padding='valid', name='1x1_1'),
    layers.Conv2D(10, (1,1), activation='relu', 
                  padding='valid', name='1x1_2'),
    layers.GlobalAveragePooling2D(name='GlobalAveragePooling2D'),
    layers.Activation('softmax')
], name = "convModel")

convModel.summary()
# Out:
# Model: "convModel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# 3x3_1 (Conv2D)               (None, 32, 32, 96)        2688
# _________________________________________________________________
# 3x3_2 (Conv2D)               (None, 32, 32, 96)        83040
# _________________________________________________________________
# poolconv_1 (Conv2D)          (None, 15, 15, 96)        83040
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 96)        0
# _________________________________________________________________
# 3x3_3 (Conv2D)               (None, 15, 15, 192)       166080
# _________________________________________________________________
# 3x3_4 (Conv2D)               (None, 15, 15, 192)       331968
# _________________________________________________________________
# poolconv_2 (Conv2D)          (None, 7, 7, 192)         331968
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 192)         0
# _________________________________________________________________
# 3x3_6 (Conv2D)               (None, 7, 7, 192)         331968
# _________________________________________________________________
# 1x1_1 (Conv2D)               (None, 7, 7, 192)         37056
# _________________________________________________________________
# 1x1_2 (Conv2D)               (None, 7, 7, 10)          1930
# _________________________________________________________________
# GlobalAveragePooling2D (Glob (None, 10)                0
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 1,369,738
# Trainable params: 1,369,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Optimizer
opt = tf.keras.optimizers.SGD(lr=0.015, momentum=0.9, decay=1e-7)
#opt = tf.keras.optimizers.Adam(
#    learning_rate=0.01,
#    beta_1=0.9,
#    beta_2=0.999,
#    epsilon=1e-07,
#    amsgrad=False,
#    name="Adam"
#)

# %%
convModel.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
BATCHSIZE = 50
EPOCHS = 50

#traingen.fit(train_images)
#traindata = traingen.flow(train_images, train_labels)

# With Augmentation
#history = convModel.fit(traingen.flow(train_images, train_labels, batch_size=BATCHSIZE), 
#                        epochs=EPOCHS, verbose=1, 
#                        validation_data=(test_images,test_labels))

# Without Augmentation
history = convModel.fit(train_images, train_labels, batch_size=BATCHSIZE, 
                        epochs=EPOCHS, verbose=1, 
                       validation_data=(test_images,test_labels))
# Out:
# Epoch 1/50
# 1000/1000 [==============================] - 10s 10ms/step - loss: 2.2917 - accuracy: 0.1208 - val_loss: 2.2638 - val_accuracy: 0.1816
# Epoch 2/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.2497 - accuracy: 0.1988 - val_loss: 2.2140 - val_accuracy: 0.2376
# Epoch 3/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.2081 - accuracy: 0.2439 - val_loss: 2.1751 - val_accuracy: 0.2789
# Epoch 4/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.1824 - accuracy: 0.2710 - val_loss: 2.1571 - val_accuracy: 0.2973
# Epoch 5/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.1679 - accuracy: 0.2857 - val_loss: 2.1503 - val_accuracy: 0.3035
# Epoch 6/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.1544 - accuracy: 0.3005 - val_loss: 2.1327 - val_accuracy: 0.3236
# Epoch 7/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.1430 - accuracy: 0.3126 - val_loss: 2.1235 - val_accuracy: 0.3332
# Epoch 8/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.1369 - accuracy: 0.3193 - val_loss: 2.1113 - val_accuracy: 0.3441
# Epoch 9/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.1243 - accuracy: 0.3321 - val_loss: 2.1052 - val_accuracy: 0.3502
# Epoch 10/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.1147 - accuracy: 0.3420 - val_loss: 2.1006 - val_accuracy: 0.3568
# Epoch 11/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.1054 - accuracy: 0.3506 - val_loss: 2.0989 - val_accuracy: 0.3576
# Epoch 12/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0975 - accuracy: 0.3600 - val_loss: 2.0886 - val_accuracy: 0.3691
# Epoch 13/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0901 - accuracy: 0.3663 - val_loss: 2.0916 - val_accuracy: 0.3648
# Epoch 14/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0862 - accuracy: 0.3703 - val_loss: 2.0749 - val_accuracy: 0.3821
# Epoch 15/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0766 - accuracy: 0.3803 - val_loss: 2.0587 - val_accuracy: 0.3989
# Epoch 16/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0697 - accuracy: 0.3868 - val_loss: 2.0546 - val_accuracy: 0.4038
# Epoch 17/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0617 - accuracy: 0.3961 - val_loss: 2.0505 - val_accuracy: 0.4067
# Epoch 18/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0582 - accuracy: 0.3990 - val_loss: 2.0483 - val_accuracy: 0.4083
# Epoch 19/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0521 - accuracy: 0.4054 - val_loss: 2.0539 - val_accuracy: 0.4031
# Epoch 20/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0445 - accuracy: 0.4123 - val_loss: 2.0414 - val_accuracy: 0.4142
# Epoch 21/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0378 - accuracy: 0.4196 - val_loss: 2.0275 - val_accuracy: 0.4310
# Epoch 22/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0372 - accuracy: 0.4204 - val_loss: 2.0234 - val_accuracy: 0.4354
# Epoch 23/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0283 - accuracy: 0.4294 - val_loss: 2.0221 - val_accuracy: 0.4358
# Epoch 24/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0251 - accuracy: 0.4328 - val_loss: 2.0123 - val_accuracy: 0.4459
# Epoch 25/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0238 - accuracy: 0.4340 - val_loss: 2.0090 - val_accuracy: 0.4497
# Epoch 26/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0167 - accuracy: 0.4414 - val_loss: 2.0093 - val_accuracy: 0.4495
# Epoch 27/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0112 - accuracy: 0.4468 - val_loss: 2.0172 - val_accuracy: 0.4407
# Epoch 28/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0072 - accuracy: 0.4505 - val_loss: 2.0026 - val_accuracy: 0.4555
# Epoch 29/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0046 - accuracy: 0.4530 - val_loss: 2.0108 - val_accuracy: 0.4462
# Epoch 30/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9994 - accuracy: 0.4589 - val_loss: 2.0017 - val_accuracy: 0.4553
# Epoch 31/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9951 - accuracy: 0.4629 - val_loss: 1.9899 - val_accuracy: 0.4691
# Epoch 32/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9921 - accuracy: 0.4665 - val_loss: 1.9891 - val_accuracy: 0.4700
# Epoch 33/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9881 - accuracy: 0.4709 - val_loss: 2.0051 - val_accuracy: 0.4526
# Epoch 34/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9873 - accuracy: 0.4710 - val_loss: 1.9964 - val_accuracy: 0.4627
# Epoch 35/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9820 - accuracy: 0.4765 - val_loss: 1.9754 - val_accuracy: 0.4834
# Epoch 36/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9782 - accuracy: 0.4805 - val_loss: 1.9705 - val_accuracy: 0.4880
# Epoch 37/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9741 - accuracy: 0.4841 - val_loss: 1.9800 - val_accuracy: 0.4784
# Epoch 38/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9686 - accuracy: 0.4895 - val_loss: 1.9718 - val_accuracy: 0.4857
# Epoch 39/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9665 - accuracy: 0.4920 - val_loss: 1.9748 - val_accuracy: 0.4833
# Epoch 40/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9667 - accuracy: 0.4918 - val_loss: 1.9660 - val_accuracy: 0.4926
# Epoch 41/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9633 - accuracy: 0.4956 - val_loss: 1.9808 - val_accuracy: 0.4769
# Epoch 42/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9620 - accuracy: 0.4963 - val_loss: 1.9650 - val_accuracy: 0.4942
# Epoch 43/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9552 - accuracy: 0.5033 - val_loss: 1.9650 - val_accuracy: 0.4944
# Epoch 44/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9557 - accuracy: 0.5027 - val_loss: 1.9633 - val_accuracy: 0.4946
# Epoch 45/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9538 - accuracy: 0.5051 - val_loss: 1.9575 - val_accuracy: 0.5010
# Epoch 46/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9493 - accuracy: 0.5097 - val_loss: 1.9571 - val_accuracy: 0.5006
# Epoch 47/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9468 - accuracy: 0.5121 - val_loss: 1.9528 - val_accuracy: 0.5053
# Epoch 48/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9463 - accuracy: 0.5131 - val_loss: 1.9539 - val_accuracy: 0.5048
# Epoch 49/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9436 - accuracy: 0.5151 - val_loss: 1.9596 - val_accuracy: 0.4991
# Epoch 50/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.9412 - accuracy: 0.5185 - val_loss: 1.9490 - val_accuracy: 0.5094

# %%
plt.plot(history.history['accuracy'], label='t_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.xlim([0, 250])
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = convModel.evaluate(test_images,  test_labels, verbose=1)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.9490 - accuracy: 0.5094

# %%
convModel.save("convCifar10")
# Out:
# INFO:tensorflow:Assets written to: convCifar10/assets

# %% [markdown]
# ## Loading and Evaluating the Model

# %%
cifar10model = models.load_model("convCifar10")

# %%
t1 = time.time()
loss, acc = cifar10model.evaluate(test_images, test_labels, verbose=2)
t2 = time.time()

print("elapsed:", (t2-t1)*1000, "ms")
print("average:", (t2-t1)*1000/(test_images.shape[0]), "ms")
# Out:
# 313/313 - 1s - loss: 1.9490 - accuracy: 0.1305
# elapsed: 1280.8759212493896 ms
# average: 0.12808759212493898 ms

# %%
# Continued Training

history = cifar10model.fit(train_images, train_labels, epochs=300,
                         validation_data=(test_images, test_labels))
# Out:
# Epoch 1/300
#  607/1563 [==========>...................] - ETA: 6s - loss: 2.0566 - accuracy: 0.1068
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-31cf7dbf4a61> in <module>
#       1 # Continued Training
#       2
# ----> 3 history = cifar10model.fit(train_images, train_labels, epochs=300,
#       4                          validation_data=(test_images, test_labels))
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1101               logs = tmp_logs  # No error, now safe to assign to logs.
#    1102               end_step = step + data_handler.step_increment
# -> 1103               callbacks.on_train_batch_end(end_step, logs)
#    1104         epoch_logs = copy.copy(logs)
#    1105
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     438     """
#     439     if self._should_call_train_batch_hooks:
# --> 440       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     441
#     442   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     287       self._call_batch_begin_hook(mode, batch, logs)
#     288     elif hook == 'end':
# --> 289       self._call_batch_end_hook(mode, batch, logs)
#     290     else:
#     291       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     307       batch_time = time.time() - self._batch_start_time
#     308
# --> 309     self._call_batch_hook_helper(hook_name, batch, logs)
#     310
#     311     if self._check_timing:
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     340       hook = getattr(callback, hook_name)
#     341       if getattr(callback, '_supports_tf_logs', False):
# --> 342         hook(batch, logs)
#     343       else:
#     344         if numpy_logs is None:  # Only convert once.
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     959
#     960   def on_train_batch_end(self, batch, logs=None):
# --> 961     self._batch_update_progbar(batch, logs)
#     962
#     963   def on_test_batch_end(self, batch, logs=None):
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1014     if self.verbose == 1:
#    1015       # Only block async when verbose = 1.
# -> 1016       logs = tf_utils.to_numpy_or_python_type(logs)
#    1017       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1018
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#     536
# --> 537   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     538
#     539
#
# /usr/lib/python3/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /usr/lib/python3/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     531   def _to_single_numpy_or_python_type(t):
#     532     if isinstance(t, ops.Tensor):
# --> 533       x = t.numpy()
#     534       return x.item() if np.ndim(x) == 0 else x
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/lib/python3/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1061     """
#    1062     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1063     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1064     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1065
#
# /usr/lib/python3/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1027   def _numpy(self):
#    1028     try:
# -> 1029       return self._numpy_internal()
#    1030     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1031       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['accuracy'], label='t_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.xlim([-1, 16])
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = newModel.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 10000/10000 - 12s - loss: 1.2541 - accuracy: 0.6078
