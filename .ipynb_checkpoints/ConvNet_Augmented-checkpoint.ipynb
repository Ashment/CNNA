# %% [markdown]
# ## Building and Training the Model

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
print("Num GPUs Available: ", tf.config.list_physical_devices('GPU'))
# Out:
# Num GPUs Available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load and preprocess dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255, test_images / 255

# %%
print("Training:",train_images.shape)
print("Testing:",test_images.shape)
# Out:
# Training: (50000, 32, 32, 3)
# Testing: (10000, 32, 32, 3)

# %%
for i in range(0,9):
    plt.subplot(330+1+i)
    plt.imshow(train_images[i])
plt.show()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
#Setup data augmentation
traingen = ImageDataGenerator(
    rotation_range=0,
    horizontal_flip=True,
    vertical_flip=False,
    width_shift_range=0.1,
    height_shift_range=0.1
    )
traingen.fit(train_images)

# %%
#Show example augmented images
for X_batch, y_batch in traingen.flow(train_images, train_labels, batch_size=9):
    for i in range(0,9):
        plt.subplot(330+1+i)
        plt.imshow(X_batch[i])
    plt.show()
    break

# %%
#make images
train_images = train_images.reshape(train_images.shape[0], 32, 32, 3)
test_images = test_images.reshape(test_images.shape[0], 32, 32, 3)
input_shape = (32, 32, 1)
print('train_images shape:', train_images.shape)
print('test_images shape:', test_images.shape)
print(train_images.shape[0], 'train samples')
print(test_images.shape[0], 'test samples')
# Out:
# train_images shape: (50000, 32, 32, 3)
# test_images shape: (10000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
convModel = models.Sequential([
    #3x3_96    
    layers.Conv2D(96, (3,3), activation='relu', input_shape=(32,32,3),
                  padding='same', name='3x3_1'),
    layers.Conv2D(96, (3,3), activation='relu', 
                  padding='same', name='3x3_2'),
    layers.Conv2D(96, (3,3), activation='relu', 
                  padding='valid', strides=[2,2], name='poolconv_1'),
    layers.Dropout(0.5),
    
    #3x3_192
    layers.Conv2D(192, (3,3), activation='relu', input_shape=(32, 32, 3),
                  padding='same', name='3x3_3'),
    layers.Conv2D(192, (3,3), activation='relu', 
                  padding='same', name='3x3_4'),
    layers.Conv2D(192, (3,3), activation='relu', 
                  padding='valid', strides=[2,2], name='poolconv_2'),
    layers.Dropout(0.5),
    
    #3x3&1x1
    layers.Conv2D(192, (3,3), activation='relu', 
                  padding='same', name='3x3_6'),
    layers.Conv2D(192, (1,1), activation='relu', 
                  padding='valid', name='1x1_1'),
    layers.Conv2D(10, (1,1), activation='relu', 
                  padding='valid', name='1x1_2'),
    layers.GlobalAveragePooling2D(name='GlobalAveragePooling2D'),
    layers.Activation('softmax')
], name = "convModel")

convModel.summary()
# Out:
# Model: "convModel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# 3x3_1 (Conv2D)               (None, 32, 32, 96)        2688
# _________________________________________________________________
# 3x3_2 (Conv2D)               (None, 32, 32, 96)        83040
# _________________________________________________________________
# poolconv_1 (Conv2D)          (None, 15, 15, 96)        83040
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 96)        0
# _________________________________________________________________
# 3x3_3 (Conv2D)               (None, 15, 15, 192)       166080
# _________________________________________________________________
# 3x3_4 (Conv2D)               (None, 15, 15, 192)       331968
# _________________________________________________________________
# poolconv_2 (Conv2D)          (None, 7, 7, 192)         331968
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 192)         0
# _________________________________________________________________
# 3x3_6 (Conv2D)               (None, 7, 7, 192)         331968
# _________________________________________________________________
# 1x1_1 (Conv2D)               (None, 7, 7, 192)         37056
# _________________________________________________________________
# 1x1_2 (Conv2D)               (None, 7, 7, 10)          1930
# _________________________________________________________________
# GlobalAveragePooling2D (Glob (None, 10)                0
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 1,369,738
# Trainable params: 1,369,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Optimizer
opt = tf.keras.optimizers.SGD(lr=0.02, momentum=0.9, decay=1e-7)

# %%
convModel.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
BATCHSIZE = 100
EPOCHS = 50

#traingen.fit(train_images)
#traindata = traingen.flow(train_images, train_labels)

# With Augmentation
#history = convModel.fit(traingen.flow(train_images, train_labels, batch_size=BATCHSIZE), 
#                        epochs=EPOCHS, verbose=1, 
#                        validation_data=(test_images,test_labels))

#Without Augmentation
history = convModel.fit(train_images, train_labels, batch_size=BATCHSIZE, 
                        epochs=EPOCHS, verbose=1, 
                        validation_data=(test_images,test_labels))
# Out:
# Epoch 1/50
#   1/500 [..............................] - ETA: 0s - loss: 2.3026 - accuracy: 0.0800WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0052s vs `on_train_batch_end` time: 0.0101s). Check your callbacks.
# 500/500 [==============================] - 8s 15ms/step - loss: 2.2599 - accuracy: 0.1696 - val_loss: 2.1888 - val_accuracy: 0.2646
# Epoch 2/50
# 500/500 [==============================] - 7s 14ms/step - loss: 2.1645 - accuracy: 0.2883 - val_loss: 2.1349 - val_accuracy: 0.3179
# Epoch 3/50
# 500/500 [==============================] - 7s 14ms/step - loss: 2.1230 - accuracy: 0.3317 - val_loss: 2.0835 - val_accuracy: 0.3714
# Epoch 4/50
# 500/500 [==============================] - 7s 14ms/step - loss: 2.0972 - accuracy: 0.3577 - val_loss: 2.0653 - val_accuracy: 0.3897
# Epoch 5/50
# 500/500 [==============================] - 7s 15ms/step - loss: 2.0763 - accuracy: 0.3788 - val_loss: 2.0480 - val_accuracy: 0.4099
# Epoch 6/50
# 500/500 [==============================] - 7s 15ms/step - loss: 2.0563 - accuracy: 0.3996 - val_loss: 2.0434 - val_accuracy: 0.4108
# Epoch 7/50
# 500/500 [==============================] - 7s 15ms/step - loss: 2.0307 - accuracy: 0.4253 - val_loss: 2.0163 - val_accuracy: 0.4400
# Epoch 8/50
# 500/500 [==============================] - 8s 15ms/step - loss: 2.0144 - accuracy: 0.4423 - val_loss: 1.9977 - val_accuracy: 0.4604
# Epoch 9/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9950 - accuracy: 0.4623 - val_loss: 2.0325 - val_accuracy: 0.4240
# Epoch 10/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9838 - accuracy: 0.4734 - val_loss: 1.9822 - val_accuracy: 0.4766
# Epoch 11/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9744 - accuracy: 0.4829 - val_loss: 1.9602 - val_accuracy: 0.4972
# Epoch 12/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9634 - accuracy: 0.4940 - val_loss: 1.9528 - val_accuracy: 0.5055
# Epoch 13/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9588 - accuracy: 0.4992 - val_loss: 1.9503 - val_accuracy: 0.5064
# Epoch 14/50
# 500/500 [==============================] - 7s 14ms/step - loss: 1.9502 - accuracy: 0.5075 - val_loss: 1.9465 - val_accuracy: 0.5118
# Epoch 15/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9431 - accuracy: 0.5144 - val_loss: 1.9448 - val_accuracy: 0.5125
# Epoch 16/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9379 - accuracy: 0.5196 - val_loss: 1.9249 - val_accuracy: 0.5325
# Epoch 17/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9277 - accuracy: 0.5302 - val_loss: 1.9231 - val_accuracy: 0.5360
# Epoch 18/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9240 - accuracy: 0.5340 - val_loss: 1.9218 - val_accuracy: 0.5366
# Epoch 19/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9205 - accuracy: 0.5378 - val_loss: 1.9172 - val_accuracy: 0.5407
# Epoch 20/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9188 - accuracy: 0.5398 - val_loss: 1.9107 - val_accuracy: 0.5480
# Epoch 21/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9198 - accuracy: 0.5387 - val_loss: 1.9193 - val_accuracy: 0.5392
# Epoch 22/50
# 500/500 [==============================] - 7s 14ms/step - loss: 1.9098 - accuracy: 0.5490 - val_loss: 1.9189 - val_accuracy: 0.5411
# Epoch 23/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9083 - accuracy: 0.5510 - val_loss: 1.9081 - val_accuracy: 0.5497
# Epoch 24/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9050 - accuracy: 0.5541 - val_loss: 1.9046 - val_accuracy: 0.5536
# Epoch 25/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9068 - accuracy: 0.5519 - val_loss: 1.8895 - val_accuracy: 0.5690
# Epoch 26/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.8977 - accuracy: 0.5617 - val_loss: 1.8962 - val_accuracy: 0.5631
# Epoch 27/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.8965 - accuracy: 0.5624 - val_loss: 1.9143 - val_accuracy: 0.5451
# Epoch 28/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.8972 - accuracy: 0.5613 - val_loss: 1.9053 - val_accuracy: 0.5543
# Epoch 29/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.8978 - accuracy: 0.5614 - val_loss: 1.9106 - val_accuracy: 0.5480
# Epoch 30/50
# 500/500 [==============================] - 7s 14ms/step - loss: 1.8948 - accuracy: 0.5641 - val_loss: 1.9019 - val_accuracy: 0.5574
# Epoch 31/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.8917 - accuracy: 0.5674 - val_loss: 1.9011 - val_accuracy: 0.5585
# Epoch 32/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.8964 - accuracy: 0.5633 - val_loss: 1.9207 - val_accuracy: 0.5395
# Epoch 33/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.8948 - accuracy: 0.5647 - val_loss: 1.9118 - val_accuracy: 0.5487
# Epoch 34/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.8979 - accuracy: 0.5611 - val_loss: 1.9197 - val_accuracy: 0.5404
# Epoch 35/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.8934 - accuracy: 0.5663 - val_loss: 1.9028 - val_accuracy: 0.5562
# Epoch 36/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.8958 - accuracy: 0.5639 - val_loss: 1.8894 - val_accuracy: 0.5703
# Epoch 37/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9019 - accuracy: 0.5581 - val_loss: 1.8801 - val_accuracy: 0.5799
# Epoch 38/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9020 - accuracy: 0.5580 - val_loss: 1.9066 - val_accuracy: 0.5532
# Epoch 39/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9098 - accuracy: 0.5502 - val_loss: 1.8995 - val_accuracy: 0.5605
# Epoch 40/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9051 - accuracy: 0.5551 - val_loss: 1.9222 - val_accuracy: 0.5387
# Epoch 41/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9033 - accuracy: 0.5569 - val_loss: 1.9081 - val_accuracy: 0.5519
# Epoch 42/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9222 - accuracy: 0.5384 - val_loss: 1.9265 - val_accuracy: 0.5335
# Epoch 43/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9174 - accuracy: 0.5431 - val_loss: 1.9029 - val_accuracy: 0.5577
# Epoch 44/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9237 - accuracy: 0.5369 - val_loss: 1.9102 - val_accuracy: 0.5506
# Epoch 45/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9344 - accuracy: 0.5261 - val_loss: 1.9284 - val_accuracy: 0.5326
# Epoch 46/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9478 - accuracy: 0.5126 - val_loss: 1.9288 - val_accuracy: 0.5315
# Epoch 47/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9486 - accuracy: 0.5122 - val_loss: 1.9157 - val_accuracy: 0.5449
# Epoch 48/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9604 - accuracy: 0.5002 - val_loss: 1.9306 - val_accuracy: 0.5300
# Epoch 49/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9732 - accuracy: 0.4878 - val_loss: 1.9569 - val_accuracy: 0.5039
# Epoch 50/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.9665 - accuracy: 0.4944 - val_loss: 2.0472 - val_accuracy: 0.4137

# %%
plt.plot(history.history['accuracy'], label='t_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.xlim([0, 250])
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = convModel.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 2.0472 - accuracy: 0.4137

# %%
convModel.save("convCifar10")
# Out:
# WARNING:tensorflow:From /usr/lib/python3/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/lib/python3/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: convCifar10/assets

# %% [markdown]
# ## Loading and Evaluating the Model

# %%
cifar10model = models.load_model("convCifar10")

# %%
t1 = time.time()
loss, acc = cifar10model.evaluate(test_images, test_labels, verbose=2)
t2 = time.time()

print("elapsed:", (t2-t1)*1000, "ms")
print("average:", (t2-t1)*1000/(test_images.shape[0]), "ms")
# Out:
# 313/313 - 1s - loss: 2.0139 - accuracy: 0.0696
# elapsed: 1341.4077758789062 ms
# average: 0.13414077758789061 ms

# %%
# Continued Training

history = cifar10model.fit(train_images, train_labels, epochs=300,
                         validation_data=(test_images, test_labels))
# Out:
# Epoch 1/300
#  607/1563 [==========>...................] - ETA: 6s - loss: 2.0566 - accuracy: 0.1068
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-31cf7dbf4a61> in <module>
#       1 # Continued Training
#       2
# ----> 3 history = cifar10model.fit(train_images, train_labels, epochs=300,
#       4                          validation_data=(test_images, test_labels))
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1101               logs = tmp_logs  # No error, now safe to assign to logs.
#    1102               end_step = step + data_handler.step_increment
# -> 1103               callbacks.on_train_batch_end(end_step, logs)
#    1104         epoch_logs = copy.copy(logs)
#    1105
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     438     """
#     439     if self._should_call_train_batch_hooks:
# --> 440       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     441
#     442   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     287       self._call_batch_begin_hook(mode, batch, logs)
#     288     elif hook == 'end':
# --> 289       self._call_batch_end_hook(mode, batch, logs)
#     290     else:
#     291       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     307       batch_time = time.time() - self._batch_start_time
#     308
# --> 309     self._call_batch_hook_helper(hook_name, batch, logs)
#     310
#     311     if self._check_timing:
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     340       hook = getattr(callback, hook_name)
#     341       if getattr(callback, '_supports_tf_logs', False):
# --> 342         hook(batch, logs)
#     343       else:
#     344         if numpy_logs is None:  # Only convert once.
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     959
#     960   def on_train_batch_end(self, batch, logs=None):
# --> 961     self._batch_update_progbar(batch, logs)
#     962
#     963   def on_test_batch_end(self, batch, logs=None):
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1014     if self.verbose == 1:
#    1015       # Only block async when verbose = 1.
# -> 1016       logs = tf_utils.to_numpy_or_python_type(logs)
#    1017       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1018
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#     536
# --> 537   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     538
#     539
#
# /usr/lib/python3/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /usr/lib/python3/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /usr/lib/python3/dist-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     531   def _to_single_numpy_or_python_type(t):
#     532     if isinstance(t, ops.Tensor):
# --> 533       x = t.numpy()
#     534       return x.item() if np.ndim(x) == 0 else x
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/lib/python3/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1061     """
#    1062     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1063     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1064     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1065
#
# /usr/lib/python3/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1027   def _numpy(self):
#    1028     try:
# -> 1029       return self._numpy_internal()
#    1030     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1031       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['accuracy'], label='t_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.xlim([-1, 16])
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = newModel.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 10000/10000 - 12s - loss: 1.2541 - accuracy: 0.6078
