# %% [markdown]
# ## Building and Training the Model

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load and preprocess dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255, test_images / 255

# %%
print("Training:",train_images.shape)
print("Testing:",test_images.shape)
# Out:
# Training: (50000, 32, 32, 3)
# Testing: (10000, 32, 32, 3)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
for i in range(0,9):
    plt.subplot(330+1+i)
    plt.imshow(train_images[i])
plt.show()

# %%
#Setup data augmentation
traingen = ImageDataGenerator(
    rotation_range=0,
    horizontal_flip=True,
    vertical_flip=False,
    width_shift_range=0.15,
    height_shift_range=0.15
    )
traingen.fit(train_images)

# %%
#Show example augmented images
for X_batch, y_batch in traingen.flow(train_images, train_labels, batch_size=9):
    for i in range(0,9):
        plt.subplot(330+1+i)
        plt.imshow(X_batch[i])
    plt.show()
    break

# %%
exModel = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', padding='same', 
                  name='3x3_1', input_shape=(32, 32, 3)),
    #layers.MaxPooling2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu', strides=[2,2], 
                  name='poolconv_1'),
    layers.Dropout(0.5),
    
    layers.Conv2D(64, (3,3), activation='relu', padding='same',
                  name='3x3_2'),
    #layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation='relu', strides=[2,2], 
                  name='poolconv_2'),
    layers.Dropout(0.5),
    
    layers.Conv2D(128, (3,3), activation='relu', padding='same', 
                  name='3x3_3'),
    #layers.MaxPooling2D((2,2)),
    layers.Conv2D(128, (3,3), activation='relu', strides=[2,2], 
                  name='poolconv_3'),
    layers.Dropout(0.5),
    
    layers.Conv2D(128, (3,3), activation='relu', padding='same', 
                  name='3x3_4'),
    layers.Conv2D(128, (1,1), activation='relu', padding='valid', 
                  name='1x1_1'),
    layers.Conv2D(10, (1,1), activation='relu', padding='valid', 
                  name='1x1_2'),
    layers.GlobalAveragePooling2D(),
    layers.Activation('softmax')
], name = "conv_model")

# %%
exModel.summary()
# Out:
# Model: "conv_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# 3x3_1 (Conv2D)               (None, 32, 32, 32)        896
# _________________________________________________________________
# poolconv_1 (Conv2D)          (None, 15, 15, 32)        9248
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# 3x3_2 (Conv2D)               (None, 15, 15, 64)        18496
# _________________________________________________________________
# poolconv_2 (Conv2D)          (None, 7, 7, 64)          36928
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# 3x3_3 (Conv2D)               (None, 7, 7, 128)         73856
# _________________________________________________________________
# poolconv_3 (Conv2D)          (None, 3, 3, 128)         147584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# 3x3_4 (Conv2D)               (None, 3, 3, 128)         147584
# _________________________________________________________________
# 1x1_1 (Conv2D)               (None, 3, 3, 128)         16512
# _________________________________________________________________
# 1x1_2 (Conv2D)               (None, 3, 3, 10)          1290
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 10)                0
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 452,394
# Trainable params: 452,394
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.SGD(lr=0.03, momentum=0.8, decay=1e-8)

exModel.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
BATCHSIZE = 100
EPOCHS = 100

# Without Augment
#history = exModel.fit(train_images, train_labels, epochs=EPOCHS, batch_size=BATCHSIZE,
#                         validation_data=(test_images, test_labels))

# With Augment
history = exModel.fit(traingen.flow(train_images, train_labels, batch_size=BATCHSIZE), 
                         epochs=EPOCHS, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.3026 - accuracy: 0.2246 - val_loss: 2.3026 - val_accuracy: 0.9929
# Epoch 2/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.3026 - accuracy: 0.7734 - val_loss: 2.3025 - val_accuracy: 0.5907
# Epoch 3/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.3025 - accuracy: 0.9835 - val_loss: 2.3025 - val_accuracy: 0.4662
# Epoch 4/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.3023 - accuracy: 0.9378 - val_loss: 2.3015 - val_accuracy: 0.9988
# Epoch 5/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2823 - accuracy: 0.6785 - val_loss: 2.2659 - val_accuracy: 0.1665
# Epoch 6/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2637 - accuracy: 0.1906 - val_loss: 2.2460 - val_accuracy: 0.2443
# Epoch 7/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2498 - accuracy: 0.0420 - val_loss: 2.2430 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2351 - accuracy: 0.0000e+00 - val_loss: 2.2162 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2174 - accuracy: 0.0262 - val_loss: 2.1843 - val_accuracy: 0.0409
# Epoch 10/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1890 - accuracy: 0.0868 - val_loss: 2.1584 - val_accuracy: 0.1099
# Epoch 11/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1757 - accuracy: 0.0783 - val_loss: 2.1725 - val_accuracy: 0.0840
# Epoch 12/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1647 - accuracy: 0.0785 - val_loss: 2.1276 - val_accuracy: 0.1024
# Epoch 13/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1506 - accuracy: 0.0838 - val_loss: 2.1071 - val_accuracy: 0.1050
# Epoch 14/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1408 - accuracy: 0.0854 - val_loss: 2.1129 - val_accuracy: 0.0963
# Epoch 15/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1369 - accuracy: 0.0776 - val_loss: 2.1283 - val_accuracy: 0.1801
# Epoch 16/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.1301 - accuracy: 0.0807 - val_loss: 2.1085 - val_accuracy: 0.12820s - loss: 2.1300 - ac
# Epoch 17/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1255 - accuracy: 0.0802 - val_loss: 2.0983 - val_accuracy: 0.0828
# Epoch 18/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1165 - accuracy: 0.0794 - val_loss: 2.0765 - val_accuracy: 0.0782
# Epoch 19/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1121 - accuracy: 0.0825 - val_loss: 2.0802 - val_accuracy: 0.1122
# Epoch 20/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1050 - accuracy: 0.0782 - val_loss: 2.0671 - val_accuracy: 0.0844
# Epoch 21/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.0992 - accuracy: 0.0830 - val_loss: 2.0992 - val_accuracy: 0.1438
# Epoch 22/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0967 - accuracy: 0.0856 - val_loss: 2.0628 - val_accuracy: 0.1486
# Epoch 23/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0909 - accuracy: 0.0897 - val_loss: 2.0500 - val_accuracy: 0.0897
# Epoch 24/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0886 - accuracy: 0.0903 - val_loss: 2.0422 - val_accuracy: 0.0886
# Epoch 25/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0831 - accuracy: 0.0920 - val_loss: 2.0698 - val_accuracy: 0.1174
# Epoch 26/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0806 - accuracy: 0.0977 - val_loss: 2.0437 - val_accuracy: 0.1409
# Epoch 27/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.
100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9529 - accuracy: 0.1054 - val_loss: 1.9065 - val_accuracy: 0.0898
# Epoch 83/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9507 - accuracy: 0.1096 - val_loss: 1.9265 - val_accuracy: 0.0785
# Epoch 84/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9552 - accuracy: 0.1087 - val_loss: 1.8988 - val_accuracy: 0.1000
# Epoch 85/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9520 - accuracy: 0.1153 - val_loss: 1.9104 - val_accuracy: 0.1199
# Epoch 86/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9500 - accuracy: 0.1056 - val_loss: 1.9051 - val_accuracy: 0.0742
# Epoch 87/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9467 - accuracy: 0.1092 - val_loss: 1.8986 - val_accuracy: 0.0908
# Epoch 88/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9498 - accuracy: 0.1111 - val_loss: 1.9050 - val_accuracy: 0.0922
# Epoch 89/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9506 - accuracy: 0.1181 - val_loss: 1.9073 - val_accuracy: 0.1129
# Epoch 90/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9525 - accuracy: 0.1143 - val_loss: 1.9083 - val_accuracy: 0.0872
# Epoch 91/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9456 - accuracy: 0.1109 - val_loss: 1.8895 - val_accuracy: 0.1068
# Epoch 92/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9437 - accuracy: 0.1096 - val_loss: 1.9013 - val_accuracy: 0.1350
# Epoch 93/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9454 - accuracy: 0.1087 - val_loss: 1.8956 - val_accuracy: 0.1279
# Epoch 94/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9434 - accuracy: 0.1085 - val_loss: 1.9098 - val_accuracy: 0.1067
# Epoch 95/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9486 - accuracy: 0.1101 - val_loss: 1.9013 - val_accuracy: 0.1046
# Epoch 96/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9455 - accuracy: 0.1112 - val_loss: 1.8928 - val_accuracy: 0.0918
# Epoch 97/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9417 - accuracy: 0.1106 - val_loss: 1.8973 - val_accuracy: 0.1159 loss: 1.9399 - accura
# Epoch 98/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9423 - accuracy: 0.1138 - val_loss: 1.8964 - val_accuracy: 0.1311
# Epoch 99/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9416 - accuracy: 0.1129 - val_loss: 1.9043 - val_accuracy: 0.0894
# Epoch 100/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9452 - accuracy: 0.1118 - val_loss: 1.9126 - val_accuracy: 0.1153

# %%
plt.plot(history.history['accuracy'], label='t_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.xlim([-1, 100])
plt.ylabel('Accuracy')
plt.ylim([0.1, 1])
plt.legend(loc='lower right')

test_loss, test_acc = exModel.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 1.9126 - accuracy: 0.1153

# %%
exModel.save("exCifar10")
# Out:
# WARNING:tensorflow:From /usr/lib/python3/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/lib/python3/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: exCifar10/assets

# %% [markdown]
# ## Loading and Evaluating the Model

# %%
cifar10model = models.load_model("exCifar10")

# %%
t1 = time.time()
loss, acc = cifar10model.evaluate(test_images, test_labels, verbose=2)
t2 = time.time()

print("elapsed:", (t2-t1)*1000, "ms")
print("average:", (t2-t1)*1000/(test_images.shape[0]), "ms")
# Out:
# 313/313 - 1s - loss: 1.9126 - accuracy: 0.1153
# elapsed: 1040.0927066802979 ms
# average: 0.10400927066802979 ms
