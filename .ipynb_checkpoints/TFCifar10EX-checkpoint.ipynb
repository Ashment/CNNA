# %% [markdown]
# ## Building and Training the Model

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load and preprocess dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255, test_images / 255

# %%
print("Training:",train_images.shape)
print("Testing:",test_images.shape)
# Out:
# Training: (50000, 32, 32, 3)
# Testing: (10000, 32, 32, 3)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
for i in range(0,9):
    plt.subplot(330+1+i)
    plt.imshow(train_images[i])
plt.show()

# %%
#Setup data augmentation
traingen = ImageDataGenerator(
    rotation_range=0,
    horizontal_flip=True,
    vertical_flip=False,
    width_shift_range=0.15,
    height_shift_range=0.15
    )
traingen.fit(train_images)

# %%
#Show example augmented images
for X_batch, y_batch in traingen.flow(train_images, train_labels, batch_size=9):
    for i in range(0,9):
        plt.subplot(330+1+i)
        plt.imshow(X_batch[i])
    plt.show()
    break

# %%
exModel = models.Sequential([
    #3x3_32
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3),
                  padding='same', name='3x3_1'),
    layers.Conv2D(32, (3,3), activation='relu', 
                  padding='same', name='3x3_2'),
    layers.MaxPool2D(),
    #layers.Conv2D(32, (3,3), activation='relu', 
    #              padding='valid', strides=[2,2], name='poolconv_1'),
    layers.Dropout(0.25),
    
    #3x3_64
    layers.Conv2D(64, (3,3), activation='relu',
                  padding='same', name='3x3_3'),
    layers.Conv2D(64, (3,3), activation='relu', 
                  padding='same', name='3x3_4'),
    layers.MaxPool2D(),
    #layers.Conv2D(64, (3,3), activation='relu', 
    #              padding='valid', strides=[2,2], name='poolconv_2'),
    layers.Dropout(0.25),
    
    #3x3_128
    layers.Conv2D(128, (3,3), activation='relu',
                  padding='same', name='3x3_5'),
    layers.Conv2D(128, (3,3), activation='relu', 
                  padding='same', name='3x3_6'),
    layers.MaxPool2D(),
    #layers.Conv2D(128, (3,3), activation='relu', 
    #              padding='valid', strides=[2,2], name='poolconv_3'),
    layers.Dropout(0.25),
    
    #3x3&1x1
    layers.Conv2D(128, (3,3), activation='relu', 
                  padding='same', name='3x3_f'),
    layers.Conv2D(128, (1,1), activation='relu', 
                  padding='valid', name='1x1_1'),
    layers.Conv2D(10, (1,1), activation='relu', 
                  padding='valid', name='1x1_2'),
    layers.GlobalAveragePooling2D(name='GlobalAveragePooling2D'),
    layers.Softmax()
], name = "conv_model")

# %%
exModel.summary()
# Out:
# Model: "conv_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# 3x3_1 (Conv2D)               (None, 32, 32, 32)        896
# _________________________________________________________________
# 3x3_2 (Conv2D)               (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# 3x3_3 (Conv2D)               (None, 16, 16, 64)        18496
# _________________________________________________________________
# 3x3_4 (Conv2D)               (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# 3x3_5 (Conv2D)               (None, 8, 8, 128)         73856
# _________________________________________________________________
# 3x3_6 (Conv2D)               (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# 3x3_f (Conv2D)               (None, 4, 4, 128)         147584
# _________________________________________________________________
# 1x1_1 (Conv2D)               (None, 4, 4, 128)         16512
# _________________________________________________________________
# 1x1_2 (Conv2D)               (None, 4, 4, 10)          1290
# _________________________________________________________________
# GlobalAveragePooling2D (Glob (None, 10)                0
# _________________________________________________________________
# softmax (Softmax)            (None, 10)                0
# =================================================================
# Total params: 452,394
# Trainable params: 452,394
# Non-trainable params: 0
# _________________________________________________________________

# %%
#opt = tf.keras.optimizers.Adam(
#    learning_rate=0.005,
#    beta_1=0.9,
#    beta_2=0.999,
#    epsilon=1e-07,
#)

opt = tf.keras.optimizers.SGD(lr = 0.01, momentum=0.9, decay=1e-8)

exModel.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['sparse_categorical_accuracy'])

# %%
BATCHSIZE = 100
EPOCHS = 100

# Without Augment
#history = exModel.fit(train_images, train_labels, epochs=EPOCHS, batch_size=BATCHSIZE,
#                         validation_data=(test_images, test_labels))

# With Augment
history = exModel.fit(traingen.flow(train_images, train_labels, batch_size=BATCHSIZE), 
                         epochs=EPOCHS, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.3025 - sparse_categorical_accuracy: 0.1020 - val_loss: 2.3024 - val_sparse_categorical_accuracy: 0.1124
# Epoch 2/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.3021 - sparse_categorical_accuracy: 0.1003 - val_loss: 2.3016 - val_sparse_categorical_accuracy: 0.1007
# Epoch 3/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2888 - sparse_categorical_accuracy: 0.1270 - val_loss: 2.2820 - val_sparse_categorical_accuracy: 0.1457
# Epoch 4/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2651 - sparse_categorical_accuracy: 0.1863 - val_loss: 2.2677 - val_sparse_categorical_accuracy: 0.1950
# Epoch 5/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2652 - sparse_categorical_accuracy: 0.1920 - val_loss: 2.2327 - val_sparse_categorical_accuracy: 0.2178
# Epoch 6/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2442 - sparse_categorical_accuracy: 0.2030 - val_loss: 2.2389 - val_sparse_categorical_accuracy: 0.2115
# Epoch 7/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2345 - sparse_categorical_accuracy: 0.2114 - val_loss: 2.2194 - val_sparse_categorical_accuracy: 0.2313
# Epoch 8/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2277 - sparse_categorical_accuracy: 0.2194 - val_loss: 2.2073 - val_sparse_categorical_accuracy: 0.2430
# Epoch 9/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2204 - sparse_categorical_accuracy: 0.2266 - val_loss: 2.2030 - val_sparse_categorical_accuracy: 0.2437
# Epoch 10/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2126 - sparse_categorical_accuracy: 0.2365 - val_loss: 2.1964 - val_sparse_categorical_accuracy: 0.2550
# Epoch 11/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.2060 - sparse_categorical_accuracy: 0.2427 - val_loss: 2.1877 - val_sparse_categorical_accuracy: 0.2653
# Epoch 12/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1970 - sparse_categorical_accuracy: 0.2535 - val_loss: 2.1739 - val_sparse_categorical_accuracy: 0.2797
# Epoch 13/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1867 - sparse_categorical_accuracy: 0.2634 - val_loss: 2.1582 - val_sparse_categorical_accuracy: 0.2913
# Epoch 14/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.1608 - sparse_categorical_accuracy: 0.2930 - val_loss: 2.1510 - val_sparse_categorical_accuracy: 0.3022
# Epoch 15/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.1494 - sparse_categorical_accuracy: 0.3028 - val_loss: 2.1232 - val_sparse_categorical_accuracy: 0.3324
# Epoch 16/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1408 - sparse_categorical_accuracy: 0.3126 - val_loss: 2.1214 - val_sparse_categorical_accuracy: 0.3317
# Epoch 17/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.1373 - sparse_categorical_accuracy: 0.3161 - val_loss: 2.1078 - val_sparse_categorical_accuracy: 0.3470
# Epoch 18/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.1309 - sparse_categorical_accuracy: 0.3220 - val_loss: 2.1225 - val_sparse_categorical_accuracy: 0.3328
# Epoch 19/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1233 - sparse_categorical_accuracy: 0.3296 - val_loss: 2.1058 - val_sparse_categorical_accuracy: 0.3466
# Epoch 20/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1191 - sparse_categorical_accuracy: 0.3341 - val_loss: 2.0951 - val_sparse_categorical_accuracy: 0.3601
# Epoch 21/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1146 - sparse_categorical_accuracy: 0.3390 - val_loss: 2.0996 - val_sparse_categorical_accuracy: 0.3519
# Epoch 22/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.1098 - sparse_categorical_accuracy: 0.3427 - val_loss: 2.0851 - val_sparse_categorical_accuracy: 0.3713
# Epoch 23/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.1038 - sparse_categorical_accuracy: 0.3496 - val_loss: 2.0948 - val_sparse_categorical_accuracy: 0.3614
# Epoch 24/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0994 - sparse_categorical_accuracy: 0.3547 - val_loss: 2.0704 - val_sparse_categorical_accuracy: 0.3859
# Epoch 25/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0934 - sparse_categorical_accuracy: 0.3613 - val_loss: 2.0809 - val_sparse_categorical_accuracy: 0.3737
# Epoch 26/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0876 - sparse_categorical_accuracy: 0.3674 - val_loss: 2.0655 - val_sparse_categorical_accuracy: 0.3898
# Epoch 27/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.0835 - sparse_categorical_accuracy: 0.3715 - val_loss: 2.0765 - val_sparse_categorical_accuracy: 0.3788
# Epoch 28/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0776 - sparse_categorical_accuracy: 0.3788 - val_loss: 2.0738 - val_sparse_categorical_accuracy: 0.3840
# Epoch 29/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0734 - sparse_categorical_accuracy: 0.3818 - val_loss: 2.0581 - val_sparse_categorical_accuracy: 0.3966
# Epoch 30/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0678 - sparse_categorical_accuracy: 0.3878 - val_loss: 2.0558 - val_sparse_categorical_accuracy: 0.3995
# Epoch 31/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0634 - sparse_categorical_accuracy: 0.3916 - val_loss: 2.0596 - val_sparse_categorical_accuracy: 0.3945
# Epoch 32/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0626 - sparse_categorical_accuracy: 0.3942 - val_loss: 2.0530 - val_sparse_categorical_accuracy: 0.4033
# Epoch 33/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0547 - sparse_categorical_accuracy: 0.4011 - val_loss: 2.0613 - val_sparse_categorical_accuracy: 0.3950
# Epoch 34/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.0513 - sparse_categorical_accuracy: 0.4057 - val_loss: 2.0597 - val_sparse_categorical_accuracy: 0.3961
# Epoch 35/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0483 - sparse_categorical_accuracy: 0.4082 - val_loss: 2.0519 - val_sparse_categorical_accuracy: 0.4022
# Epoch 36/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0441 - sparse_categorical_accuracy: 0.4126 - val_loss: 2.0209 - val_sparse_categorical_accuracy: 0.4336
# Epoch 37/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0400 - sparse_categorical_accuracy: 0.4160 - val_loss: 2.0299 - val_sparse_categorical_accuracy: 0.4284
# Epoch 38/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0341 - sparse_categorical_accuracy: 0.4230 - val_loss: 2.0132 - val_sparse_categorical_accuracy: 0.4451
# Epoch 39/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.0320 - sparse_categorical_accuracy: 0.4253 - val_loss: 2.0007 - val_sparse_categorical_accuracy: 0.4574
# Epoch 40/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.0277 - sparse_categorical_accuracy: 0.4294 - val_loss: 1.9996 - val_sparse_categorical_accuracy: 0.4582
# Epoch 41/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0234 - sparse_categorical_accuracy: 0.4339 - val_loss: 2.0015 - val_sparse_categorical_accuracy: 0.4571
# Epoch 42/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0187 - sparse_categorical_accuracy: 0.4388 - val_loss: 2.0095 - val_sparse_categorical_accuracy: 0.4456
# Epoch 43/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.0159 - sparse_categorical_accuracy: 0.4423 - val_loss: 2.0050 - val_sparse_categorical_accuracy: 0.4521
# Epoch 44/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0109 - sparse_categorical_accuracy: 0.4459 - val_loss: 2.0083 - val_sparse_categorical_accuracy: 0.4492
# Epoch 45/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.0097 - sparse_categorical_accuracy: 0.4478 - val_loss: 2.0055 - val_sparse_categorical_accuracy: 0.4524
# Epoch 46/100
# 500/500 [==============================] - 18s 35ms/step - loss: 2.0051 - sparse_categorical_accuracy: 0.4526 - val_loss: 2.0103 - val_sparse_categorical_accuracy: 0.4471
# Epoch 47/100
# 500/500 [==============================] - 18s 36ms/step - loss: 2.0044 - sparse_categorical_accuracy: 0.4533 - val_loss: 1.9791 - val_sparse_categorical_accuracy: 0.4780
# Epoch 48/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9996 - sparse_categorical_accuracy: 0.4582 - val_loss: 1.9995 - val_sparse_categorical_accuracy: 0.4576
# Epoch 49/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9983 - sparse_categorical_accuracy: 0.4587 - val_loss: 1.9701 - val_sparse_categorical_accuracy: 0.4876
# Epoch 50/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9948 - sparse_categorical_accuracy: 0.4632 - val_loss: 1.9899 - val_sparse_categorical_accuracy: 0.4660
# Epoch 51/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9904 - sparse_categorical_accuracy: 0.4684 - val_loss: 1.9963 - val_sparse_categorical_accuracy: 0.4612
# Epoch 52/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9899 - sparse_categorical_accuracy: 0.4680 - val_loss: 1.9623 - val_sparse_categorical_accuracy: 0.4941
# Epoch 53/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9886 - sparse_categorical_accuracy: 0.4689 - val_loss: 1.9651 - val_sparse_categorical_accuracy: 0.4923
# Epoch 54/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9836 - sparse_categorical_accuracy: 0.4740 - val_loss: 1.9591 - val_sparse_categorical_accuracy: 0.4977
# Epoch 55/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9816 - sparse_categorical_accuracy: 0.4758 - val_loss: 1.9871 - val_sparse_categorical_accuracy: 0.4710
# Epoch 56/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9806 - sparse_categorical_accuracy: 0.4774 - val_loss: 1.9589 - val_sparse_categorical_accuracy: 0.4987
# Epoch 57/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9763 - sparse_categorical_accuracy: 0.4822 - val_loss: 1.9768 - val_sparse_categorical_accuracy: 0.4795
# Epoch 58/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9739 - sparse_categorical_accuracy: 0.4840 - val_loss: 1.9588 - val_sparse_categorical_accuracy: 0.4994
# Epoch 59/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9727 - sparse_categorical_accuracy: 0.4851 - val_loss: 1.9631 - val_sparse_categorical_accuracy: 0.4948
# Epoch 60/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9725 - sparse_categorical_accuracy: 0.4853 - val_loss: 1.9483 - val_sparse_categorical_accuracy: 0.5101
# Epoch 61/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9677 - sparse_categorical_accuracy: 0.4899 - val_loss: 1.9481 - val_sparse_categorical_accuracy: 0.5109
# Epoch 62/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9664 - sparse_categorical_accuracy: 0.4925 - val_loss: 1.9503 - val_sparse_categorical_accuracy: 0.5091
# Epoch 63/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9652 - sparse_categorical_accuracy: 0.4924 - val_loss: 1.9542 - val_sparse_categorical_accuracy: 0.5042
# Epoch 64/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9621 - sparse_categorical_accuracy: 0.4963 - val_loss: 1.9509 - val_sparse_categorical_accuracy: 0.5076
# Epoch 65/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9612 - sparse_categorical_accuracy: 0.4970 - val_loss: 1.9604 - val_sparse_categorical_accuracy: 0.4967
# Epoch 66/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9580 - sparse_categorical_accuracy: 0.4999 - val_loss: 1.9424 - val_sparse_categorical_accuracy: 0.5158
# Epoch 67/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9581 - sparse_categorical_accuracy: 0.4994 - val_loss: 1.9652 - val_sparse_categorical_accuracy: 0.4937
# Epoch 68/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9560 - sparse_categorical_accuracy: 0.5021 - val_loss: 1.9337 - val_sparse_categorical_accuracy: 0.5257
# Epoch 69/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9550 - sparse_categorical_accuracy: 0.5031 - val_loss: 1.9299 - val_sparse_categorical_accuracy: 0.5293
# Epoch 70/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9507 - sparse_categorical_accuracy: 0.5079 - val_loss: 1.9348 - val_sparse_categorical_accuracy: 0.5243
# Epoch 71/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9490 - sparse_categorical_accuracy: 0.5095 - val_loss: 1.9347 - val_sparse_categorical_accuracy: 0.5233
# Epoch 72/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9468 - sparse_categorical_accuracy: 0.5118 - val_loss: 1.9354 - val_sparse_categorical_accuracy: 0.5237
# Epoch 73/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9483 - sparse_categorical_accuracy: 0.5100 - val_loss: 1.9219 - val_sparse_categorical_accuracy: 0.5379
# Epoch 74/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9432 - sparse_categorical_accuracy: 0.5154 - val_loss: 1.9343 - val_sparse_categorical_accuracy: 0.5240
# Epoch 75/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9445 - sparse_categorical_accuracy: 0.5142 - val_loss: 1.9330 - val_sparse_categorical_accuracy: 0.5246
# Epoch 76/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9395 - sparse_categorical_accuracy: 0.5194 - val_loss: 1.9247 - val_sparse_categorical_accuracy: 0.5332
# Epoch 77/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9416 - sparse_categorical_accuracy: 0.5169 - val_loss: 1.9299 - val_sparse_categorical_accuracy: 0.5274
# Epoch 78/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9389 - sparse_categorical_accuracy: 0.5202 - val_loss: 1.9288 - val_sparse_categorical_accuracy: 0.5293
# Epoch 79/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9384 - sparse_categorical_accuracy: 0.5194 - val_loss: 1.9179 - val_sparse_categorical_accuracy: 0.5409
# Epoch 80/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9367 - sparse_categorical_accuracy: 0.5217 - val_loss: 1.9149 - val_sparse_categorical_accuracy: 0.5428
# Epoch 81/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9351 - sparse_categorical_accuracy: 0.5234 - val_loss: 1.9394 - val_sparse_categorical_accuracy: 0.5177
# Epoch 82/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9329 - sparse_categorical_accuracy: 0.5254 - val_loss: 1.9174 - val_sparse_categorical_accuracy: 0.5400
# Epoch 83/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9303 - sparse_categorical_accuracy: 0.5285 - val_loss: 1.9091 - val_sparse_categorical_accuracy: 0.5484
# Epoch 84/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9298 - sparse_categorical_accuracy: 0.5289 - val_loss: 1.9356 - val_sparse_categorical_accuracy: 0.5212
# Epoch 85/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9273 - sparse_categorical_accuracy: 0.5310 - val_loss: 1.9085 - val_sparse_categorical_accuracy: 0.5510
# Epoch 86/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9259 - sparse_categorical_accuracy: 0.5327 - val_loss: 1.9172 - val_sparse_categorical_accuracy: 0.5388
# Epoch 87/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9279 - sparse_categorical_accuracy: 0.5304 - val_loss: 1.9148 - val_sparse_categorical_accuracy: 0.5425
# Epoch 88/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9256 - sparse_categorical_accuracy: 0.5336 - val_loss: 1.9111 - val_sparse_categorical_accuracy: 0.5488
# Epoch 89/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9226 - sparse_categorical_accuracy: 0.5361 - val_loss: 1.9321 - val_sparse_categorical_accuracy: 0.5267
# Epoch 90/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9182 - sparse_categorical_accuracy: 0.5403 - val_loss: 1.9022 - val_sparse_categorical_accuracy: 0.5561
# Epoch 91/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9216 - sparse_categorical_accuracy: 0.5364 - val_loss: 1.9042 - val_sparse_categorical_accuracy: 0.5541
# Epoch 92/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9191 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.9256 - val_sparse_categorical_accuracy: 0.5323
# Epoch 93/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9165 - sparse_categorical_accuracy: 0.5415 - val_loss: 1.9003 - val_sparse_categorical_accuracy: 0.5583
# Epoch 94/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9165 - sparse_categorical_accuracy: 0.5419 - val_loss: 1.9041 - val_sparse_categorical_accuracy: 0.5530
# Epoch 95/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9146 - sparse_categorical_accuracy: 0.5437 - val_loss: 1.9155 - val_sparse_categorical_accuracy: 0.5421
# Epoch 96/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9132 - sparse_categorical_accuracy: 0.5455 - val_loss: 1.9051 - val_sparse_categorical_accuracy: 0.5537
# Epoch 97/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9125 - sparse_categorical_accuracy: 0.5461 - val_loss: 1.8977 - val_sparse_categorical_accuracy: 0.5616
# Epoch 98/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9095 - sparse_categorical_accuracy: 0.5491 - val_loss: 1.8986 - val_sparse_categorical_accuracy: 0.5588
# Epoch 99/100
# 500/500 [==============================] - 18s 36ms/step - loss: 1.9109 - sparse_categorical_accuracy: 0.5475 - val_loss: 1.9128 - val_sparse_categorical_accuracy: 0.5450
# Epoch 100/100
# 500/500 [==============================] - 18s 35ms/step - loss: 1.9086 - sparse_categorical_accuracy: 0.5490 - val_loss: 1.9021 - val_sparse_categorical_accuracy: 0.5565

# %%
plt.plot(history.history['sparse_categorical_accuracy'], label='t_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.xlim([-1, 100])
plt.ylabel('Accuracy')
plt.ylim([0.1, 1])
plt.legend(loc='lower right')

test_loss, test_acc = exModel.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 1.9021 - sparse_categorical_accuracy: 0.5565

# %%
exModel.save("exCifar10")
# Out:
# WARNING:tensorflow:From /usr/lib/python3/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/lib/python3/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: exCifar10/assets

# %% [markdown]
# ## Loading and Evaluating the Model

# %%
cifar10model = models.load_model("exCifar10")

# %%
t1 = time.time()
loss, acc = cifar10model.evaluate(test_images, test_labels, verbose=2)
t2 = time.time()

print("elapsed:", (t2-t1)*1000, "ms")
print("average:", (t2-t1)*1000/(test_images.shape[0]), "ms")
# Out:
# 313/313 - 1s - loss: 1.9021 - sparse_categorical_accuracy: 0.5565
# elapsed: 1001.2052059173584 ms
# average: 0.10012052059173585 ms
