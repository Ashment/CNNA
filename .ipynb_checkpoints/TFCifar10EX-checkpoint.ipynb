# %% [markdown]
# ## Building and Training the Model

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load and preprocess dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255, test_images / 255

# %%
print("Training:",train_images.shape)
print("Testing:",test_images.shape)
# Out:
# Training: (50000, 32, 32, 3)
# Testing: (10000, 32, 32, 3)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
for i in range(0,9):
    plt.subplot(330+1+i)
    plt.imshow(train_images[i])
plt.show()

# %%
#Setup data augmentation
traingen = ImageDataGenerator(
    rotation_range=0,
    horizontal_flip=True,
    vertical_flip=False,
    width_shift_range=0.15,
    height_shift_range=0.15
    )
traingen.fit(train_images)

# %%
#Show example augmented images
for X_batch, y_batch in traingen.flow(train_images, train_labels, batch_size=9):
    for i in range(0,9):
        plt.subplot(330+1+i)
        plt.imshow(X_batch[i])
    plt.show()
    break

# %%
basicModel = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', padding='same', 
                  name='3x3_1', input_shape=(32, 32, 3)),
    #layers.MaxPooling2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu', strides=[2,2], 
                  name='poolconv_1'),
    layers.Dropout(0.5),
    
    layers.Conv2D(64, (3,3), activation='relu', padding='same',
                  name='3x3_2'),
    layers.Conv2D(64, (3,3), activation='relu', padding='same', 
                  name='3x3_3'),
    layers.Conv2D(64, (3,3), activation='relu', padding='same', 
                  name='3x3_4'),
    #layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation='relu', strides=[2,2], 
                  name='poolconv_2'),
    layers.Dropout(0.5),
    
    layers.Conv2D(64, (3,3), activation='relu', padding='same', 
                  name='3x3_5'),
    layers.Conv2D(64, (1,1), activation='relu', padding='valid', 
                  name='1x1_1'),
    layers.Conv2D(10, (1,1), activation='relu', padding='valid', 
                  name='1x1_2'),
    layers.GlobalAveragePooling2D(),
    layers.Softmax()
], name = "basic_model")

# %%
basicModel.summary()
# Out:
# Model: "basic_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# 3x3_1 (Conv2D)               (None, 32, 32, 32)        896
# _________________________________________________________________
# poolconv_1 (Conv2D)          (None, 15, 15, 32)        9248
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# 3x3_2 (Conv2D)               (None, 15, 15, 64)        18496
# _________________________________________________________________
# 3x3_3 (Conv2D)               (None, 15, 15, 64)        36928
# _________________________________________________________________
# 3x3_4 (Conv2D)               (None, 15, 15, 64)        36928
# _________________________________________________________________
# poolconv_2 (Conv2D)          (None, 7, 7, 64)          36928
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# 3x3_5 (Conv2D)               (None, 7, 7, 64)          36928
# _________________________________________________________________
# 1x1_1 (Conv2D)               (None, 7, 7, 64)          4160
# _________________________________________________________________
# 1x1_2 (Conv2D)               (None, 7, 7, 10)          650
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 10)                0
# _________________________________________________________________
# softmax (Softmax)            (None, 10)                0
# =================================================================
# Total params: 181,162
# Trainable params: 181,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.SGD(lr=0.03, momentum=0.8, decay=5e-8)

basicModel.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
BATCHSIZE = 50
EPOCHS = 85

# Without Augment
#history = basicModel.fit(train_images, train_labels, epochs=EPOCHS, batch_size=BATCHSIZE,
#                         validation_data=(test_images, test_labels))

# With Augment
history = basicModel.fit(traingen.flow(train_images, train_labels, batch_size=BATCHSIZE), 
                         epochs=EPOCHS, validation_data=(test_images, test_labels))
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1000 steps, validate on 10000 samples
# Epoch 1/85
# 1000/1000 [==============================] - 89s 89ms/step - loss: 2.2970 - accuracy: 0.1071 - val_loss: 2.2663 - val_accuracy: 0.1599
# Epoch 2/85
# 1000/1000 [==============================] - 89s 89ms/step - loss: 2
85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0843 - accuracy: 0.3733 - val_loss: 2.0701 - val_accuracy: 0.3878
# Epoch 65/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0852 - accuracy: 0.3720 - val_loss: 2.0765 - val_accuracy: 0.3830
# Epoch 66/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0836 - accuracy: 0.3741 - val_loss: 2.0747 - val_accuracy: 0.3832
# Epoch 67/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0844 - accuracy: 0.3737 - val_loss: 2.0678 - val_accuracy: 0.3903
# Epoch 68/85
# 1000/1000 [==============================] - 90s 90ms/step - loss: 2.0818 - accuracy: 0.3758 - val_loss: 2.0681 - val_accuracy: 0.3899
# Epoch 69/85
# 1000/1000 [==============================] - 90s 90ms/step - loss: 2.0851 - accuracy: 0.3727 - val_loss: 2.0660 - val_accuracy: 0.3916
# Epoch 70/85
# 1000/1000 [==============================] - 90s 90ms/step - loss: 2.0794 - accuracy: 0.3786 - val_loss: 2.0630 - val_accuracy: 0.3945
# Epoch 71/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0805 - accuracy: 0.3770 - val_loss: 2.0726 - val_accuracy: 0.3850
# Epoch 72/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0775 - accuracy: 0.3800 - val_loss: 2.0600 - val_accuracy: 0.3981
# Epoch 73/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0794 - accuracy: 0.3783 - val_loss: 2.0591 - val_accuracy: 0.3988
# Epoch 74/85
# 1000/1000 [==============================] - 90s 90ms/step - loss: 2.0755 - accuracy: 0.3823 - val_loss: 2.0633 - val_accuracy: 0.3940
# Epoch 75/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0784 - accuracy: 0.3791 - val_loss: 2.0671 - val_accuracy: 0.3907
# Epoch 76/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0775 - accuracy: 0.3809 - val_loss: 2.0677 - val_accuracy: 0.3885
# Epoch 77/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0742 - accuracy: 0.3835 - val_loss: 2.0574 - val_accuracy: 0.4011
# Epoch 78/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0755 - accuracy: 0.3818 - val_loss: 2.0536 - val_accuracy: 0.4051
# Epoch 79/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0723 - accuracy: 0.3853 - val_loss: 2.0528 - val_accuracy: 0.4063
# Epoch 80/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0732 - accuracy: 0.3844 - val_loss: 2.0533 - val_accuracy: 0.4052
# Epoch 81/85
# 1000/1000 [==============================] - 92s 92ms/step - loss: 2.0702 - accuracy: 0.3870 - val_loss: 2.0528 - val_accuracy: 0.4043
# Epoch 82/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0701 - accuracy: 0.3874 - val_loss: 2.0586 - val_accuracy: 0.4000
# Epoch 83/85
# 1000/1000 [==============================] - 91s 91ms/step - loss: 2.0725 - accuracy: 0.3850 - val_loss: 2.0568 - val_accuracy: 0.4016
# Epoch 84/85
# 1000/1000 [==============================] - 92s 92ms/step - loss: 2.0708 - accuracy: 0.3871 - val_loss: 2.0503 - val_accuracy: 0.4087
# Epoch 85/85
# 1000/1000 [==============================] - 92s 92ms/step - loss: 2.0696 - accuracy: 0.3882 - val_loss: 2.0543 - val_accuracy: 0.4042

# %%
plt.plot(history.history['accuracy'], label='t_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.xlim([-1, 100])
plt.ylabel('Accuracy')
plt.ylim([0.1, 1])
plt.legend(loc='lower right')

test_loss, test_acc = basicModel.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 10000/10000 - 3s - loss: 2.0543 - accuracy: 0.4042

# %%
basicModel.save("exCifar10")
# Out:
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: exCifar10/assets

# %% [markdown]
# ## Loading and Evaluating the Model

# %%
cifar10model = models.load_model("basicCifar10")

# %%
t1 = time.time()
loss, acc = cifar10model.evaluate(test_images, test_labels, verbose=2)
t2 = time.time()

print("elapsed:", (t2-t1)*1000, "ms")
print("average:", (t2-t1)*1000/(test_images.shape[0]), "ms")
# Out:
# 10000/10000 - 1s - loss: 0.8569 - accuracy: 0.7111
# elapsed: 1125.0970363616943 ms
# average: 0.11250970363616944 ms
