# %% [markdown]
# ## Building and Training the Model

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load and preprocess dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255, test_images / 255

# %%
print("Training:",train_images.shape)
print("Testing:",test_images.shape)
# Out:
# Training: (50000, 32, 32, 3)
# Testing: (10000, 32, 32, 3)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
for i in range(0,9):
    plt.subplot(330+1+i)
    plt.imshow(train_images[i])
plt.show()

# %%
#Setup data augmentation
traingen = ImageDataGenerator(
    rotation_range=0,
    horizontal_flip=True,
    vertical_flip=False,
    width_shift_range=0.15,
    height_shift_range=0.15
    )
traingen.fit(train_images)

# %%
#Show example augmented images
for X_batch, y_batch in traingen.flow(train_images, train_labels, batch_size=9):
    for i in range(0,9):
        plt.subplot(330+1+i)
        plt.imshow(X_batch[i])
    plt.show()
    break

# %%
basicModel = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    #layers.MaxPooling2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu', strides=[2,2]),
    layers.Dropout(0.5),
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    #layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation='relu', strides=[2,2]),
    layers.Dropout(0.5),
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.Conv2D(64, (1,1), activation='relu', padding='valid'),
    layers.Conv2D(10, (1,1), activation='relu', padding='valid'),
    layers.GlobalAveragePooling2D(),
    layers.Softmax()
], name = "basic_model")

# %%
basicModel.summary()
# Out:
# Model: "basic_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 15, 15, 32)        9248
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        36928
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 64)          4160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 10)          650
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 10)                0
# _________________________________________________________________
# softmax (Softmax)            (None, 10)                0
# =================================================================
# Total params: 144,234
# Trainable params: 144,234
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.SGD(lr=0.025, momentum=0.8, decay=1e-7)

basicModel.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
BATCHSIZE = 50
EPOCHS = 50

# Without Augment
#history = basicModel.fit(train_images, train_labels, epochs=EPOCHS, batch_size=BATCHSIZE,
#                         validation_data=(test_images, test_labels))

# With Augment
history = basicModel.fit(traingen.flow(train_images, train_labels, batch_size=BATCHSIZE), 
                         epochs=EPOCHS, validation_data=(test_images, test_labels))
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1000 steps, validate on 10000 samples
# Epoch 1/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 2.2420 - accuracy: 0.1926 - val_loss: 2.1504 - val_accuracy: 0.2991
# Epoch 2/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 2.1634 - accuracy: 0.2871 - val_loss: 2.1430 - val_accuracy: 0.3081
# Epoch 3/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 2.1230 - accuracy: 0.3298 - val_loss: 2.0983 - val_accuracy: 0.3555
# Epoch 4/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 2.0997 - accuracy: 0.3541 - val_loss: 2.0688 - val_accuracy: 0.3875
# Epoch 5/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 2.0751 - accuracy: 0.3800 - val_loss: 2.0131 - val_accuracy: 0.4427
# Epoch 6/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 2.0487 - accuracy: 0.4052 - val_loss: 1.9941 - val_accuracy: 0.4652
# Epoch 7/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 2.0311 - accuracy: 0.4248 - val_loss: 1.9875 - val_accuracy: 0.4679
# Epoch 8/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 2.0194 - accuracy: 0.4357 - val_loss: 1.9706 - val_accuracy: 0.4862
# Epoch 9/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 2.0095 - accuracy: 0.4457 - val_loss: 1.9649 - val_accuracy: 0.4898
# Epoch 10/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 2.0029 - accuracy: 0.4523 - val_loss: 1.9746 - val_accuracy: 0.4817
# Epoch 11/50
# 1000/1000 [==============================] - 72s 72ms/step - loss: 1.9850 - accuracy: 0.4701 - val_loss: 1.9498 - val_accuracy: 0.5053
# Epoch 12/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 1.9845 - accuracy: 0.4723 - val_loss: 1.9658 - val_accuracy: 0.4918
# Epoch 13/50
# 1000/1000 [==============================] - 71s 71ms/step - loss: 1.9754 - accuracy: 0.4815 - val_loss: 1.9304 - val_accuracy: 0.5277
# Epoch 14/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9652 - accuracy: 0.4904 - val_loss: 1.9175 - val_accuracy: 0.5390
# Epoch 15/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9630 - accuracy: 0.4939 - val_loss: 1.9281 - val_accuracy: 0.5282
# Epoch 16/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9581 - accuracy: 0.4994 - val_loss: 1.9511 - val_accuracy: 0.5067
# Epoch 17/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9515 - accuracy: 0.5050 - val_loss: 1.9044 - val_accuracy: 0.5522
# Epoch 18/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9486 - accuracy: 0.5076 - val_loss: 1.8995 - val_accuracy: 0.5585
# Epoch 19/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9445 - accuracy: 0.5123 - val_loss: 1.9161 - val_accuracy: 0.5420
# Epoch 20/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9383 - accuracy: 0.5185 - val_loss: 1.8988 - val_accuracy: 0.5588
# Epoch 21/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9342 - accuracy: 0.5225 - val_loss: 1.8928 - val_accuracy: 0.5650
# Epoch 22/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9268 - accuracy: 0.5308 - val_loss: 1.8779 - val_accuracy: 0.5810
# Epoch 23/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9275 - accuracy: 0.5297 - val_loss: 1.8824 - val_accuracy: 0.5755
# Epoch 24/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9229 - accuracy: 0.5351 - val_loss: 1.8800 - val_accuracy: 0.5779
# Epoch 25/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9242 - accuracy: 0.5338 - val_loss: 1.8642 - val_accuracy: 0.5944
# Epoch 26/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9246 - accuracy: 0.5331 - val_loss: 1.8855 - val_accuracy: 0.5741
# Epoch 27/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9200 - accuracy: 0.5379 - val_loss: 1.8857 - val_accuracy: 0.5730
# Epoch 28/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9218 - accuracy: 0.5363 - val_loss: 1.8684 - val_accuracy: 0.5896
# Epoch 29/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9153 - accuracy: 0.5426 - val_loss: 1.8893 - val_accuracy: 0.5687
# Epoch 30/50
# 1000/1000 [==============================] - 67s 67ms/step - loss: 1.9167 - accuracy: 0.5416 - val_loss: 1.8809 - val_accuracy: 0.5780
# Epoch 31/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9115 - accuracy: 0.5473 - val_loss: 1.8568 - val_accuracy: 0.6029
# Epoch 32/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9162 - accuracy: 0.5421 - val_loss: 1.9201 - val_accuracy: 0.5395
# Epoch 33/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9199 - accuracy: 0.5390 - val_loss: 1.8611 - val_accuracy: 0.5980
# Epoch 34/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9131 - accuracy: 0.5453 - val_loss: 1.8572 - val_accuracy: 0.6023
# Epoch 35/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9107 - accuracy: 0.5483 - val_loss: 1.8654 - val_accuracy: 0.5927
# Epoch 36/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9078 - accuracy: 0.5508 - val_loss: 1.8739 - val_accuracy: 0.5850
# Epoch 37/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9041 - accuracy: 0.5547 - val_loss: 1.8725 - val_accuracy: 0.5871
# Epoch 38/50
# 1000/1000 [==============================] - 68s 68ms/step - loss: 1.9164 - accuracy: 0.5426 - val_loss: 1.8730 - val_accuracy: 0.5863
# Epoch 39/50
# 1000/1000 [==============================] - 69s 69ms/step - loss: 1.9166 - accuracy: 0.5421 - val_loss: 1.8767 - val_accuracy: 0.5827
# Epoch 40/50
# 1000/1000 [==============================] - 73s 73ms/step - loss: 1.9172 - accuracy: 0.5419 - val_loss: 1.8936 - val_accuracy: 0.5655
# Epoch 41/50
# 1000/1000 [==============================] - 73s 73ms/step - loss: 1.9229 - accuracy: 0.5368 - val_loss: 1.8720 - val_accuracy: 0.5874
# Epoch 42/50
# 1000/1000 [==============================] - 73s 73ms/step - loss: 1.9232 - accuracy: 0.5358 - val_loss: 1.8603 - val_accuracy: 0.5997
# Epoch 43/50
# 1000/1000 [==============================] - 72s 72ms/step - loss: 1.9233 - accuracy: 0.5363 - val_loss: 1.8441 - val_accuracy: 0.6158
# Epoch 44/50
# 1000/1000 [==============================] - 72s 72ms/step - loss: 1.9283 - accuracy: 0.5316 - val_loss: 1.8708 - val_accuracy: 0.5883
# Epoch 45/50
# 1000/1000 [==============================] - 72s 72ms/step - loss: 1.9249 - accuracy: 0.5348 - val_loss: 1.8634 - val_accuracy: 0.5968
# Epoch 46/50
# 1000/1000 [==============================] - 72s 72ms/step - loss: 1.9311 - accuracy: 0.5288 - val_loss: 1.8885 - val_accuracy: 0.5714
# Epoch 47/50
# 1000/1000 [==============================] - 72s 72ms/step - loss: 1.9235 - accuracy: 0.5367 - val_loss: 1.8595 - val_accuracy: 0.6007
# Epoch 48/50
# 1000/1000 [==============================] - 72s 72ms/step - loss: 1.9225 - accuracy: 0.5376 - val_loss: 1.8752 - val_accuracy: 0.5851
# Epoch 49/50
# 1000/1000 [==============================] - 73s 73ms/step - loss: 1.9408 - accuracy: 0.5193 - val_loss: 1.9103 - val_accuracy: 0.5507
# Epoch 50/50
# 1000/1000 [==============================] - 73s 73ms/step - loss: 1.9500 - accuracy: 0.5100 - val_loss: 1.9192 - val_accuracy: 0.5413

# %%
plt.plot(history.history['accuracy'], label='t_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.xlim([-1, 100])
plt.ylabel('Accuracy')
plt.ylim([0.1, 1])
plt.legend(loc='lower right')

test_loss, test_acc = basicModel.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 10000/10000 - 2s - loss: 1.9192 - accuracy: 0.5413

# %%
basicModel.save("basicCifar10")
# Out:
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: basicCifar10/assets

# %% [markdown]
# ## Loading and Evaluating the Model

# %%
cifar10model = models.load_model("basicCifar10")

# %%
t1 = time.time()
loss, acc = cifar10model.evaluate(test_images, test_labels, verbose=2)
t2 = time.time()

print("elapsed:", (t2-t1)*1000, "ms")
print("average:", (t2-t1)*1000/(test_images.shape[0]), "ms")
# Out:
# 10000/10000 - 1s - loss: 0.8569 - accuracy: 0.7111
# elapsed: 1080.589771270752 ms
# average: 0.1080589771270752 ms
