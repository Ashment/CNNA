# %% [markdown]
# ## Building and Training the Model

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras import datasets, layers, models

# %%
# Load and preprocess dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255, test_images / 255

# %%
print("Training:",train_images.shape)
print("Testing:",test_images.shape)
# Out:
# Training: (50000, 32, 32, 3)
# Testing: (10000, 32, 32, 3)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i+100], cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i+100][0]])
plt.show()

# %%
newModel = models.Sequential([
    layers.Conv2D(96, (3,3), activation='relu', padding='same', input_shape=(32, 32, 3), name='3x3_1'),
    layers.Conv2D(96, (3,3), activation='relu', padding='same', name='3x3_2'),
    layers.Conv2D(96, (3,3), activation='relu', strides=[2,2], kernel_regularizer='l2', name='poolconv_1'),
    layers.Conv2D(192, (3,3), activation='relu', padding='same', name='3x3_3'),
    layers.Conv2D(192, (3,3), activation='relu', padding='same', name='3x3_4'),
    layers.Conv2D(192, (3,3), activation='relu', strides=[2,2], kernel_regularizer='l2', name='poolconv_2'),
    layers.Conv2D(192, (3,3), activation='relu', padding='same', name='3x3_5'),
    layers.Conv2D(192, (1,1), activation='relu', padding='same', name='3x3_6'),
    layers.Flatten(),
    layers.Dense(10, kernel_regularizer='l2')
], name = "newModel")

newModel.summary()
# Out:
# Model: "newModel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 32, 32, 96)        2688
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 32, 32, 96)        83040
# _________________________________________________________________
# poolconv_1 (Conv2D)          (None, 15, 15, 96)        83040
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 15, 15, 192)       166080
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 15, 15, 192)       331968
# _________________________________________________________________
# poolconv_2 (Conv2D)          (None, 7, 7, 192)         331968
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 7, 7, 192)         331968
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 7, 7, 192)         37056
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 9408)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                94090
# =================================================================
# Total params: 1,461,898
# Trainable params: 1,461,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
newModel.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = newModel.fit(train_images, train_labels, epochs=20,
                         validation_data=(test_images, test_labels))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 331s 7ms/sample - loss: 1.8350 - accuracy: 0.3646 - val_loss: 1.6057 - val_accuracy: 0.4457
# Epoch 2/20
# 50000/50000 [==============================] - 333s 7ms/sample - loss: 1.4976 - accuracy: 0.4919 - val_loss: 1.4313 - val_accuracy: 0.5150
# Epoch 3/20
# 50000/50000 [==============================] - 332s 7ms/sample - loss: 1.3766 - accuracy: 0.5449 - val_loss: 1.3846 - val_accuracy: 0.5422
# Epoch 4/20
# 50000/50000 [==============================] - 332s 7ms/sample - loss: 1.2679 - accuracy: 0.5896 - val_loss: 1.2240 - val_accuracy: 0.6113
# Epoch 5/20
# 50000/50000 [==============================] - 334s 7ms/sample - loss: 1.1806 - accuracy: 0.6275 - val_loss: 1.1605 - val_accuracy: 0.6347
# Epoch 6/20
# 50000/50000 [==============================] - 337s 7ms/sample - loss: 1.1148 - accuracy: 0.6539 - val_loss: 1.1271 - val_accuracy: 0.6471
# Epoch 7/20
# 50000/50000 [==============================] - 331s 7ms/sample - loss: 1.0513 - accuracy: 0.6763 - val_loss: 1.0430 - val_accuracy: 0.6819
# Epoch 8/20
# 50000/50000 [==============================] - 335s 7ms/sample - loss: 1.0011 - accuracy: 0.6965 - val_loss: 1.0370 - val_accuracy: 0.6899
# Epoch 9/20
# 50000/50000 [==============================] - 337s 7ms/sample - loss: 0.9613 - accuracy: 0.7105 - val_loss: 1.0069 - val_accuracy: 0.6955
# Epoch 10/20
# 50000/50000 [==============================] - 336s 7ms/sample - loss: 0.9241 - accuracy: 0.7256 - val_loss: 0.9505 - val_accuracy: 0.7188
# Epoch 11/20
# 50000/50000 [==============================] - 335s 7ms/sample - loss: 0.8878 - accuracy: 0.7399 - val_loss: 0.9528 - val_accuracy: 0.7219
# Epoch 12/20
# 50000/50000 [==============================] - 337s 7ms/sample - loss: 0.8569 - accuracy: 0.7502 - val_loss: 0.9237 - val_accuracy: 0.7350
# Epoch 13/20
# 50000/50000 [==============================] - 336s 7ms/sample - loss: 0.8326 - accuracy: 0.7603 - val_loss: 0.9465 - val_accuracy: 0.7224
# Epoch 14/20
# 50000/50000 [==============================] - 334s 7ms/sample - loss: 0.8100 - accuracy: 0.7699 - val_loss: 0.9357 - val_accuracy: 0.7245
# Epoch 15/20
# 50000/50000 [==============================] - 336s 7ms/sample - loss: 0.7827 - accuracy: 0.7781 - val_loss: 0.9429 - val_accuracy: 0.7296
# Epoch 16/20
# 50000/50000 [==============================] - 337s 7ms/sample - loss: 0.7646 - accuracy: 0.7839 - val_loss: 0.9537 - val_accuracy: 0.7321
# Epoch 17/20
# 50000/50000 [==============================] - 338s 7ms/sample - loss: 0.7529 - accuracy: 0.7906 - val_loss: 0.9101 - val_accuracy: 0.7415
# Epoch 18/20
# 50000/50000 [==============================] - 340s 7ms/sample - loss: 0.7299 - accuracy: 0.7976 - val_loss: 0.9071 - val_accuracy: 0.7476
# Epoch 19/20
# 50000/50000 [==============================] - 332s 7ms/sample - loss: 0.7166 - accuracy: 0.8029 - val_loss: 0.9231 - val_accuracy: 0.7372
# Epoch 20/20
# 50000/50000 [==============================] - 337s 7ms/sample - loss: 0.7042 - accuracy: 0.8087 - val_loss: 0.8700 - val_accuracy: 0.7569

# %%
plt.plot(history.history['accuracy'], label='t_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.xlim([-1, 16])
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = newModel.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 10000/10000 - 15s - loss: 0.8700 - accuracy: 0.7569

# %%
newModel.save("newCifar10")
# Out:
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: newCifar10/assets

# %% [markdown]
# ## Loading and Evaluating the Model

# %%
cifar10model = models.load_model("newCifar10")

# %%
t1 = time.time()
loss, acc = cifar10model.evaluate(test_images, test_labels, verbose=2)
t2 = time.time()

print("elapsed:", (t2-t1)*1000, "ms")
print("average:", (t2-t1)*1000/(test_images.shape[0]), "ms")
# Out:
# 10000/10000 - 15s - loss: 0.8700 - accuracy: 0.7569
# elapsed: 15123.142004013062 ms
# average: 1.5123142004013062 ms

# %%
# Continued Training

history = cifar10model.fit(train_images, train_labels, epochs=10,
                         validation_data=(test_images, test_labels))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 321s 6ms/sample - loss: 0.7161 - accuracy: 0.7990 - val_loss: 0.9229 - val_accuracy: 0.7328
# Epoch 2/10
# 50000/50000 [==============================] - 326s 7ms/sample - loss: 0.7047 - accuracy: 0.8073 - val_loss: 0.9055 - val_accuracy: 0.7375
# Epoch 3/10
# 50000/50000 [==============================] - 326s 7ms/sample - loss: 0.6981 - accuracy: 0.8085 - val_loss: 0.8724 - val_accuracy: 0.7513
# Epoch 4/10
# 50000/50000 [==============================] - 327s 7ms/sample - loss: 0.6812 - accuracy: 0.8144 - val_loss: 0.8994 - val_accuracy: 0.7502
# Epoch 5/10
# 50000/50000 [==============================] - 326s 7ms/sample - loss: 0.6735 - accuracy: 0.8184 - val_loss: 0.9080 - val_accuracy: 0.7492
# Epoch 6/10
# 50000/50000 [==============================] - 330s 7ms/sample - loss: 0.6605 - accuracy: 0.8225 - val_loss: 0.8928 - val_accuracy: 0.7540
# Epoch 7/10
# 50000/50000 [==============================] - 332s 7ms/sample - loss: 0.6557 - accuracy: 0.8233 - val_loss: 0.8702 - val_accuracy: 0.7624
# Epoch 8/10
# 50000/50000 [==============================] - 332s 7ms/sample - loss: 0.6463 - accuracy: 0.8293 - val_loss: 0.8848 - val_accuracy: 0.7560
# Epoch 9/10
# 50000/50000 [==============================] - 332s 7ms/sample - loss: 0.6343 - accuracy: 0.8327 - val_loss: 0.9474 - val_accuracy: 0.7419
# Epoch 10/10
# 50000/50000 [==============================] - 331s 7ms/sample - loss: 0.6302 - accuracy: 0.8356 - val_loss: 0.9064 - val_accuracy: 0.7495

# %%
plt.plot(history.history['accuracy'], label='t_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.xlim([-1, 16])
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = newModel.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 10000/10000 - 14s - loss: 0.8770 - accuracy: 0.7504
